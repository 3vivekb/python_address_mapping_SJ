# %% [markdown]
# Evaulating openaddresses.io data and looking at the bad datapoints using folium.

# %%
import pandas as pd

# %%
homes = pd.read_csv("city_of_san_jose.csv", dtype=str)

# %%
homes.head()
# Out:
#             LON         LAT NUMBER         STREET UNIT CITY DISTRICT REGION  \
# 0  -121.8426919  37.3217905   1151  TURTLEROCK DR  NaN  NaN      NaN    NaN
# 1  -121.9180119  37.3798761    150     CHARCOT AV  NaN  NaN      NaN    NaN
# 2   -121.916936  37.3801437   2191      ZANKER RD  NaN  NaN      NaN    NaN
# 3  -121.8534366  37.2811095    NaN            NaN  NaN  NaN      NaN    NaN
# 4  -121.9154487  37.3784567   2075      ZANKER RD  NaN  NaN      NaN    NaN
#
#   POSTCODE        ID
# 0      NaN  47742041
# 1      NaN  23711069
# 2      NaN  23711070
# 3      NaN  45566C04
# 4      NaN  23711053

# %%
homes.dtypes
# Out:
# LON         object
# LAT         object
# NUMBER      object
# STREET      object
# UNIT        object
# CITY        object
# DISTRICT    object
# REGION      object
# POSTCODE    object
# ID          object
# dtype: object

# %%
help(pd.to_numeric)
# Out:
# Help on function to_numeric in module pandas.tools.util:
#
# to_numeric(arg, errors='raise')
#     Convert argument to a numeric type.
#
#     Parameters
#     ----------
#     arg : list, tuple or array of objects, or Series
#     errors : {'ignore', 'raise', 'coerce'}, default 'raise'
#         - If 'raise', then invalid parsing will raise an exception
#         - If 'coerce', then invalid parsing will be set as NaN
#         - If 'ignore', then invalid parsing will return the input
#
#     Returns
#     -------
#     ret : numeric if parsing succeeded.
#         Return type depends on input.  Series if Series, otherwise ndarray
#
#     Examples
#     --------
#     Take separate series and convert to numeric, coercing when told to
#
#     >>> import pandas as pd
#     >>> s = pd.Series(['1.0', '2', -3])
#     >>> pd.to_numeric(s)
#     >>> s = pd.Series(['apple', '1.0', '2', -3])
#     >>> pd.to_numeric(s, errors='ignore')
#     >>> pd.to_numeric(s, errors='coerce')

# %%
pd.to_numeric(homes['LAT'], errors='raise').dtype
# Out:
# dtype('float64')

# %%
homes.dtypes
# Out:
# LON         object
# LAT         object
# NUMBER      object
# STREET      object
# UNIT        object
# CITY        object
# DISTRICT    object
# REGION      object
# POSTCODE    object
# ID          object
# dtype: object

# %%
pd.to_msgpack(homes['STREET'])

# %%
import folium

# Get a basic world map.
homes_map = folium.Map(location=[37.30, -121.9], zoom_start=10)

# %%
# Draw markers on the map.
counter = 0
record = 0
for what, row in homes.iterrows():
    if not pd.isnull(row["STREET"]):
        #Make points with street names GREEN
        folium.Marker(location=[row["LAT"], row["LON"]], popup=row["ID"], icon=folium.Icon(color='green')).add_to(homes_map)

    
    else:
        #Make points without street names RED
        folium.Marker(location=[row["LAT"], row["LON"]], popup=row["ID"], icon=folium.Icon(color='red')).add_to(homes_map)
    counter += 1
    if(counter == 500):
        break
# Create and show the map.

# %%
counter
# Out:
# 500

# %%
homes_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
homes_map.save('homes_good_bad.html')

# %%
homes['STREET'][3]
# Out:
# nan

# %%
homes['STREET'][2]
# Out:
# 'ZANKER RD'

# %%
pd.isnull(homes['STREET'][2])
# Out:
# False

# %%
pd.isnull(homes['STREET'][3])
# Out:
# True

# %%
counter
# Out:
# 500

# %%
homes.count() #Returns non-NaN in each
# Out:
# LON         245511
# LAT         245511
# NUMBER      212057
# STREET      211246
# UNIT             0
# CITY             0
# DISTRICT         0
# REGION           0
# POSTCODE         0
# ID          245464
# dtype: int64

# %%
homes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 245511 entries, 0 to 245510
# Data columns (total 10 columns):
# LON         245511 non-null object
# LAT         245511 non-null object
# NUMBER      212057 non-null object
# STREET      211246 non-null object
# UNIT        0 non-null object
# CITY        0 non-null object
# DISTRICT    0 non-null object
# REGION      0 non-null object
# POSTCODE    0 non-null object
# ID          245464 non-null object
# dtypes: object(10)
# memory usage: 20.6+ MB

# %%
homes[4060:4070]
# Out:
#                LON         LAT NUMBER      STREET UNIT CITY DISTRICT REGION  \
# 4060   -121.923705  37.2662207   3111     TODD WY  NaN  NaN      NaN    NaN
# 4061  -121.9237087  37.2664065   3091     TODD WY  NaN  NaN      NaN    NaN
# 4062  -121.9240973  37.2664054   3090     FAWN DR  NaN  NaN      NaN    NaN
# 4063   -121.941274   37.248426   2291  CARLTON AV  NaN  NaN      NaN    NaN
# 4064  -121.9420576  37.2484779   2313  CARLTON AV  NaN  NaN      NaN    NaN
# 4065  -121.9422694   37.248477   2317  CARLTON AV  NaN  NaN      NaN    NaN
# 4066  -121.9340764  37.3770059    NaN         NaN  NaN  NaN      NaN    NaN
# 4067  -121.7847685  37.3399944    NaN         NaN  NaN  NaN      NaN    NaN
# 4068  -121.9335575  37.3943987    NaN         NaN  NaN  NaN      NaN    NaN
# 4069  -121.9424814  37.2484762   2323  CARLTON AV  NaN  NaN      NaN    NaN
#
#      POSTCODE        ID
# 4060      NaN  41906061
# 4061      NaN  41906062
# 4062      NaN  41906063
# 4063      NaN  42110014
# 4064      NaN  42110084
# 4065      NaN  42110085
# 4066      NaN       NaN
# 4067      NaN  65211029
# 4068      NaN  10130005
# 4069      NaN  42110086

# %%
pd.isnull(homes['STREET'][4069])
# Out:
# False
